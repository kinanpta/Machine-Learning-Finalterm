# %% [markdown]
# # UAS_FraudDetection (Converted)
# Folder `UAS_FraudDetection.ipynb` diubah menjadi file notebook yang valid.
# Konten asli folder kosong, jadi notebook ini hanya berisi sel penjelasan.

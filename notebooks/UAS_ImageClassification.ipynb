# %% [markdown]
# # UAS_ImageClassification (Converted)
# Folder `UAS_ImageClassification` diubah menjadi file notebook yang valid.
# Konten asli folder kosong, jadi notebook ini hanya berisi sel penjelasan.
